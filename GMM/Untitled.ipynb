# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from sklearn.metrics import silhouette_score
mpl.rc('axes',labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

PROJECT_ROOT_DIR="."


def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
np.random.seed(42)
#产生实验数据
file_path="D:/study/ml/数据/ae信号/主频分类.xlsx"
df=pd.read_excel(file_path,sheet_name="汇总")

X=df["RA"]
X=X.values.reshape(-1,1)
y=df["AF"]
print(X.shape)
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=2).fit(X)
labels = gmm.predict(X)

plt.scatter(X,y, c=labels, s=4, cmap='viridis')
save_fig("汇总")
# Out:
# (1568, 1)
# Saving figure 汇总

# %%
dfn=np.array(df)


dfnc = np.insert(dfn, 0, values=labels, axis=1)

dfnc=pd.DataFrame(dfnc)
print(dfnc.info())
dfnc.to_excel('dfnc.xlsx',index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1568 entries, 0 to 1567
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1568 non-null   float64
#  1   1       1568 non-null   float64
#  2   2       1568 non-null   float64
# dtypes: float64(3)
# memory usage: 36.9 KB
# None

# %%
silhouette_score(X,labels)
# Out:
# 0.670787772940756

# %%
# def plot_decision_boundary(model, X, y):
#     # Set min and max values and give it some padding
#     x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
#     y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
#     h = 0.01
#     print( x_min, x_max)
#     # Generate a grid of points with distance h between them
#     xx, yy = np.meshgrid(1, np.linspace(y_min, y_max, 1568))
#     # Predict the function value for the whole grid
#     Z = model(np.c_[xx.ravel(), yy.ravel()])

#     Z =Z.reshape(xx.shape)
#     # Plot the contour and training examples
#     plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
#     plt.ylabel('x2')
#     plt.xlabel('x1')
#     plt.scatter(X[0, :], X[1, :], c=y.ravel(), cmap=plt.cm.Spectral)
# plot_decision_boundary(lambda x :labels,X,y)

# %%
from sklearn.decomposition import PCA

pca=PCA(n_components=0.9)
dfp=pca.fit_transform(df)


# X=dfp["RA"]
# X=X.values.reshape(-1,1)
# y=dfp["AF"]

# X = X[:, ::-1] 
X=dfp
gmm = GaussianMixture(n_components=2).fit(X)
labels = gmm.predict(X)

#plt.scatter(X,y, c=labels, s=4, cmap='viridis')

# %%
silhouette_score(X,labels)
# Out:
# 0.7114063111295473

# %%
file_path="D:/study/ml/数据/ae信号/主频分类.xlsx"
df1=pd.read_excel(file_path,sheet_name="Sheet1")

X=df1["RA值"]
X=X.values.reshape(-1,1)
y=df1["AF值"]

X = X[:, ::-1] 

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=2).fit(X)
labels1 = gmm.predict(X)
plt.scatter(X,y, c=labels1, s=4, cmap='viridis');
save_fig("Sheet1")
# Out:
# Saving figure Sheet1

# %%
dfn=np.array(df1)


dfnc = np.insert(dfn, 0, values=labels1, axis=1)

dfnc=pd.DataFrame(dfnc)
print(dfnc.info())
dfnc.to_excel('dfnc_sheet1.xlsx',index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       91 non-null     float64
#  1   1       91 non-null     float64
#  2   2       91 non-null     float64
#  3   3       0 non-null      float64
#  4   4       91 non-null     float64
# dtypes: float64(5)
# memory usage: 3.7 KB
# None

# %%
file_path="D:/study/ml/数据/ae信号/主频分类.xlsx"
df2=pd.read_excel(file_path,sheet_name="Sheet2")

X=df2["RA"]
X=X.values.reshape(-1,1)
y=df2["AF"]

X = X[:, ::-1] 

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=2).fit(X)
labels2 = gmm.predict(X)
plt.scatter(X,y, c=labels2, s=4, cmap='viridis');
save_fig("Sheet2")
# Out:
# Saving figure Sheet2

# %%
dfn=np.array(df2)


dfnc = np.insert(dfn, 0, values=labels2, axis=1)

dfnc=pd.DataFrame(dfnc)
print(dfnc.info())
dfnc.to_excel('dfnc_sheet2.xlsx',index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       69 non-null     float64
#  1   1       69 non-null     float64
#  2   2       69 non-null     float64
#  3   3       0 non-null      float64
#  4   4       69 non-null     float64
# dtypes: float64(5)
# memory usage: 2.8 KB
# None

# %%
file_path="D:/study/ml/数据/ae信号/主频分类.xlsx"
df3=pd.read_excel(file_path,sheet_name="Sheet3")

X=df3["RA"]
X=X.values.reshape(-1,1)
y=df3["AF"]
y=y.values.reshape(-1,1)
print(X.shape)
print(y.shape)
X = X[:, ::-1] 

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=2).fit(X)
labels3 = gmm.predict(X)
plt.scatter(X,y, c=labels3, s=4, cmap='viridis');
save_fig("Sheet3")
# Out:
# (792, 1)
# (792, 1)
# Saving figure Sheet3

# %%
dfn=np.array(df3)


dfnc = np.insert(dfn, 0, values=labels3, axis=1)

dfnc=pd.DataFrame(dfnc)
print(dfnc.info())
dfnc.to_excel('dfnc_sheet3.xlsx',index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       792 non-null    float64
#  1   1       792 non-null    float64
#  2   2       792 non-null    float64
#  3   3       0 non-null      float64
#  4   4       792 non-null    float64
#  5   5       0 non-null      float64
#  6   6       0 non-null      float64
#  7   7       792 non-null    float64
# dtypes: float64(8)
# memory usage: 49.6 KB
# None

# %%
file_path="D:/study/ml/数据/ae信号/主频分类.xlsx"
df4=pd.read_excel(file_path,sheet_name="Sheet4")

X=df4["RA"]
X=X.values.reshape(-1,1)
y=df4["AF"]
y=y.values.reshape(-1,1)
print(X.shape)
print(y.shape)
X = X[:, ::-1] 

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=2).fit(X)
labels4 = gmm.predict(X)
plt.scatter(X,y, c=labels4, s=4, cmap='viridis');
save_fig("Sheet4")
# Out:
# (616, 1)
# (616, 1)
# Saving figure Sheet4

# %%
dfn=np.array(df4)


dfnc = np.insert(dfn, 0, values=labels4, axis=1)

dfnc=pd.DataFrame(dfnc)
print(dfnc.info())
dfnc.to_excel('dfnc_sheet4.xlsx',index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       616 non-null    float64
#  1   1       616 non-null    float64
#  2   2       616 non-null    float64
#  3   3       0 non-null      float64
#  4   4       616 non-null    float64
#  5   5       0 non-null      float64
#  6   6       616 non-null    float64
# dtypes: float64(7)
# memory usage: 33.8 KB
# None

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

#产生实验数据
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=400, centers=4,
                       cluster_std=0.60, random_state=0)
print(X.shape)

from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=4).fit(X)
labels = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis');
# Out:
# (400, 2)
# D:\study\anaconda\envs\Test\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)
